# %%
# %cd project/
# Out:
# /home/rapids/notebooks/project

# %%
from skmob.utils.plot import plot_gdf
from skmob.tessellation import tilers
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

from skmob.utils import utils
from math import pi, asin, sin, cos, sqrt

pd.set_option('display.max_columns', 500)



# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib.offsetbox import AnchoredText
plt.rcParams["figure.figsize"] = (12, 9) # (w, h)

# %%
def distance_earth_km(src, dest):

    lat1, lat2 = src['lat']*pi/180, dest['lat']*pi/180
    lon1, lon2 = src['lon']*pi/180, dest['lon']*pi/180
    dlat, dlon = lat1-lat2, lon1-lon2

    ds = 2 * asin(sqrt(sin(dlat/2.0) ** 2 + cos(lat1) * cos(lat2) * sin(dlon/2.0) ** 2))
    return 6371.01 * ds

# %%
def filter_tessellation_land(tessellation, shape_file_land):    
    tiles_in_land = gpd.sjoin(tessellation, shape_file_land, how='left', op='intersects')
    tiles_in_land = tiles_in_land.groupby(['tile_ID'],sort=False,as_index=False).first()
    #land = tiles_in_land.dropna().drop(["index_right","boro_code","boro_name","shape_area","shape_leng"],axis=1)
    #water = tiles_in_land[tiles_in_land['index_right'].isnull()].drop(["index_right","boro_code","boro_name","shape_area","shape_leng"],axis=1)    
    
    land = tiles_in_land.dropna()[['tile_ID', 'geometry']]
    water = tiles_in_land[tiles_in_land['index_right'].isnull()][['tile_ID', 'geometry']]     
    
    crs = {'init': 'epsg:4326'}    
    land = gpd.GeoDataFrame(land, crs=crs, geometry='geometry')
    water = gpd.GeoDataFrame(water, crs=crs, geometry='geometry')     
    return {"land":land, "water":water}

# %%
def compute_distance_matrix(tess):

    lats_lngs = tess.geometry.apply(utils.get_geom_centroid, args=[True]).values
    
    distance_matrix = np.zeros((len(tess),len(tess)))

    for i in range(0,len(tess)):
        for j in range(0,len(tess)):
            if i != j:
                d = distance_earth_km({'lat':lats_lngs[i][0],'lon':lats_lngs[i][1]},
                                         {'lat':lats_lngs[j][0],'lon':lats_lngs[j][1]})
                distance_matrix[i,j] = d
                
    return distance_matrix

# %%
shape_file_land = gpd.read_file("./barriosCABA.geojson")

meters = 2612.61
tessellation = tilers.tiler.get("squared", meters=meters, base_shape=shape_file_land)
tessellation
# Out:
# /opt/conda/lib/python3.11/site-packages/skmob/tessellation/tilers.py:111: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   cascaded_union(polygons), crs=base_shape.crs)
#    tile_ID                                           geometry
# 0        0  POLYGON ((-58.53152 -34.68599, -58.53152 -34.6...
# 1        1  POLYGON ((-58.53152 -34.66669, -58.53152 -34.6...
# 2        2  POLYGON ((-58.53152 -34.64739, -58.53152 -34.6...
# 3        3  POLYGON ((-58.53152 -34.62808, -58.53152 -34.6...
# 4        4  POLYGON ((-58.53152 -34.60876, -58.53152 -34.5...
# ..     ...                                                ...
# 59      59  POLYGON ((-58.36723 -34.60876, -58.36723 -34.5...
# 60      60  POLYGON ((-58.36723 -34.58945, -58.36723 -34.5...
# 61      61  POLYGON ((-58.34376 -34.64739, -58.34376 -34.6...
# 62      62  POLYGON ((-58.34376 -34.62808, -58.34376 -34.6...
# 63      63  POLYGON ((-58.34376 -34.60876, -58.34376 -34.5...
#
# [64 rows x 2 columns]

# %%
plot_gdf(tessellation, style_func_args={'fillColor':'gray', 'color':'black', 'opacity': 0.2}, zoom = 9)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_987680205b8e6b40a4fd80d2c7743893 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_987680205b8e6b40a4fd80d2c7743893&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_987680205b8e6b40a4fd80d2c7743893 = L.map(
#                 &quot;map_987680205b8e6b40a4fd80d2c7743893&quot;,
#                 {
#                     center: [-34.612372936931024, -58.440571899292834],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_987680205b8e6b40a4fd80d2c7743893);
#
#
#
#
#
#             var tile_layer_e211b272a9c944622cca1dda0f1e621c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e211b272a9c944622cca1dda0f1e621c.addTo(map_987680205b8e6b40a4fd80d2c7743893);
#
#
#         function geo_json_c64cc5e675ceb4d5f79d861ee065d45b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.25, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c64cc5e675ceb4d5f79d861ee065d45b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c64cc5e675ceb4d5f79d861ee065d45b = L.geoJson(null, {
#                 onEachFeature: geo_json_c64cc5e675ceb4d5f79d861ee065d45b_onEachFeature,
#
#                 style: geo_json_c64cc5e675ceb4d5f79d861ee065d45b_styler,
#         });
#
#         function geo_json_c64cc5e675ceb4d5f79d861ee065d45b_add (data) {
#             geo_json_c64cc5e675ceb4d5f79d861ee065d45b
#                 .addData(data);
#         }
#             geo_json_c64cc5e675ceb4d5f79d861ee065d45b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-58.53151611470252, -34.685994060382804], [-58.53151611470252, -34.66669325685824], [-58.508046639758085, -34.66669325685824], [-58.508046639758085, -34.685994060382804], [-58.53151611470252, -34.685994060382804]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_c64cc5e675ceb4d5f79d861ee065d45b.addTo(map_987680205b8e6b40a4fd80d2c7743893);
#
#
#         function geo_json_ff070b661d660df97fa72c37d33a9dba_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.25, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ff070b661d660df97fa72c37d33a9dba_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ff070b661d660df97fa72c37d33a9dba = L.geoJson(null, {
#                 onEachFeature: geo_json_ff070b661d660df97fa72c37d33a9dba_onEachFeature,
#
#                 style: geo_json_ff070b661d660df97fa72c37d33a9dba_styler,
#         });
#
#         function geo_json_ff070b661d660df97fa72c37d33a9dba_add (data) {
#             geo_json_ff070b661d660df97fa72c37d33a9dba
#                 .addData(data);
#         }
#             geo_json_ff070b661d660df97fa72c37d33a9dba_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-58.53151611470252, -34.66669325685824], [-58.53151611470252, -34.64738795587222], [-58.508046639758085, -34.64738795587222], [-58.508046639758085, -34.66669325685824], [-58.53151611470252, -34.66669325685824]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_ff070b661d660df97fa72c37d33a9dba.addTo(map_987680205b8e6b40a4fd80d2c7743893);
#
#
#         function geo_json_7af16aeb0e4f9a77ff25343e9b8d16b5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.25, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_7af16aeb0e4f9a77ff25343e9b8d16b5_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7af16aeb0e4f9a77ff25343e9b8d16b5 = L.geoJson(null, {
#                 onEachFeature: geo_json_7af16aeb0e4f9a77ff25343e9b8d16b5_onEachFeature,
#
#                 style: geo_json_7af16aeb0e4f9a77ff25343e9b8d16b5_styler,
#         });
#
#         function geo_json_7af16aeb0e4f9a77ff25343e9b8d16b5_add (data) {

# %%
dist = compute_distance_matrix(tessellation)
dist
# Out:
# array([[ 0.        ,  2.14640485,  4.29330973, ..., 17.70176717,
#         18.34316055, 19.20473353],
#        [ 2.14640485,  0.        ,  2.14690488, ..., 17.30889825,
#         17.70589002, 18.34743174],
#        [ 4.29330973,  2.14690488,  0.        , ..., 17.17723659,
#         17.31292861, 17.71001181],
#        ...,
#        [17.70176717, 17.30889825, 17.17723659, ...,  0.        ,
#          2.14740479,  4.29530935],
#        [18.34316055, 17.70589002, 17.31292861, ...,  2.14740479,
#          0.        ,  2.14790456],
#        [19.20473353, 18.34743174, 17.71001181, ...,  4.29530935,
#          2.14790456,  0.        ]])

# %%
np.save("./generations/sem/dist_mat.npy", dist)
np.save("./generations/dia/dist_mat.npy", dist)

# %%
alls = pd.read_csv("./datasets/all_trips.csv")
