# %%
# %cd project/
# Out:
# /home/rapids/notebooks/project

# %%
# %env SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True
# %pip install -r "requirements.txt"
# Out:
# env: SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (3.9.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: folium in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.17.0)
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: shapely in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (2.0.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: contextily in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (1.6.2)
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (2.4.1)
# Requirement already satisfied: cutnorm in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (0.1.9)
# Requirement already satisfied: scikit-mobility in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (1.2.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 32)) (3.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (4.66.4)
# Collecting fiona (from -r requirements.txt (line 36))
#   Downloading fiona-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas[performance] in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (8.26.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.11/site-packages (from ipykernel->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas[performance]->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas[performance]->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas[performance]->-r requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: bottleneck>=1.3.6 in /opt/conda/lib/python3.11/site-packages (from pandas[performance]->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: numba>=0.56.4 in /opt/conda/lib/python3.11/site-packages (from pandas[performance]->-r requirements.txt (line 3)) (0.60.0)
# Requirement already satisfied: numexpr>=2.8.4 in /opt/conda/lib/python3.11/site-packages (from pandas[performance]->-r requirements.txt (line 3)) (2.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 4)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from folium->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.11/site-packages (from folium->-r requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from folium->-r requirements.txt (line 6)) (2.32.3)
# Requirement already satisfied: xyzservices in /opt/conda/lib/python3.11/site-packages (from folium->-r requirements.txt (line 6)) (2024.6.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.11/site-packages (from geopandas->-r requirements.txt (line 7)) (0.7.2)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.11/site-packages (from geopandas->-r requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 18)) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 18)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 18)) (3.5.0)
# Requirement already satisfied: geopy in /opt/conda/lib/python3.11/site-packages (from contextily->-r requirements.txt (line 27)) (2.4.1)
# Requirement already satisfied: mercantile in /opt/conda/lib/python3.11/site-packages (from contextily->-r requirements.txt (line 27)) (1.2.1)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.11/site-packages (from contextily->-r requirements.txt (line 27)) (1.3.11)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (1.13.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.11/site-packages (from torch->-r requirements.txt (line 28)) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->-r requirements.txt (line 28)) (12.6.68)
# Requirement already satisfied: sklearn in /opt/conda/lib/python3.11/site-packages (from cutnorm->-r requirements.txt (line 30)) (0.0.post12)
# Requirement already satisfied: python-igraph in /opt/conda/lib/python3.11/site-packages (from scikit-mobility->-r requirements.txt (line 31)) (0.11.6)
# Requirement already satisfied: powerlaw in /opt/conda/lib/python3.11/site-packages (from scikit-mobility->-r requirements.txt (line 31)) (1.5)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.11/site-packages (from scikit-mobility->-r requirements.txt (line 31)) (0.14.2)
# Requirement already satisfied: geojson in /opt/conda/lib/python3.11/site-packages (from scikit-mobility->-r requirements.txt (line 31)) (3.1.0)
# Requirement already satisfied: h3 in /opt/conda/lib/python3.11/site-packages (from scikit-mobility->-r requirements.txt (line 31)) (3.7.7)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.11/site-packages (from fiona->-r requirements.txt (line 36)) (23.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from fiona->-r requirements.txt (line 36)) (2024.6.2)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.11/site-packages (from fiona->-r requirements.txt (line 36)) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.11/site-packages (from fiona->-r requirements.txt (line 36)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.11/site-packages (from fiona->-r requirements.txt (line 36)) (0.7.2)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 6)) (2.1.5)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 1)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba>=0.56.4->pandas[performance]->-r requirements.txt (line 3)) (0.43.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas[performance]->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/conda/lib/python3.11/site-packages (from geopy->contextily->-r requirements.txt (line 27)) (2.0)
# Requirement already satisfied: mpmath in /opt/conda/lib/python3.11/site-packages (from powerlaw->scikit-mobility->-r requirements.txt (line 31)) (1.3.0)
# Requirement already satisfied: igraph==0.11.6 in /opt/conda/lib/python3.11/site-packages (from python-igraph->scikit-mobility->-r requirements.txt (line 31)) (0.11.6)
# Requirement already satisfied: texttable>=1.6.2 in /opt/conda/lib/python3.11/site-packages (from igraph==0.11.6->python-igraph->scikit-mobility->-r requirements.txt (line 31)) (1.7.0)
# Requirement already satisfied: affine in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily->-r requirements.txt (line 27)) (2.4.0)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily->-r requirements.txt (line 27)) (1.4.7)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from rasterio->contextily->-r requirements.txt (line 27)) (70.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->folium->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->folium->-r requirements.txt (line 6)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->folium->-r requirements.txt (line 6)) (1.26.19)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.11/site-packages (from statsmodels->scikit-mobility->-r requirements.txt (line 31)) (0.5.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.2)
# Downloading fiona-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 29.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: fiona
# Successfully installed fiona-1.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from handlers import *

import numpy as np
from sklearn.model_selection import train_test_split
import itertools
from random import sample
import pickle
from scipy.spatial import distance
import time
import sys

import random
random.seed(3110)

# %%
# if len(sys.argv) == 1: #no arguments
# cities = ["CHI", "NYC"]
# transps = ["Bike", "Taxi"]
# models = ["Gravity", "Radiation", "MoGAN", "Random_Weighted", "WMoGAN"]
models = ["WMoGAN" ]


# else:
#     cities = [sys.argv[1]]
#     transps = [sys.argv[2]]
#     if sys.argv[3] == "all":
#         models = ["Gravity", "Radiation", "MoGAN"]
#     elif sys.argv[3] == "all+R":
#         models = ["Gravity", "Radiation", "MoGAN", "Random_Weighted"]
#     else:
#         models = sys.argv[3:]

print(models)
# Out:
# ['WMoGAN']

# %%
FLAG_cpc = False
FLAG_cutnorm = False
FLAG_degree = False
FLAG_indegree = False
FLAG_outdegree = False
FLAG_topo = False # TODO
FLAG_weights = False
FLAG_weights_dist = False
FLAG_rmse = False
FLAG_kernel = False

# %%
FLAG_cpc = False
FLAG_cutnorm = False
FLAG_degree = False
FLAG_indegree = False
FLAG_outdegree = False
FLAG_topo = False # TODO
FLAG_weights = False
FLAG_weights_dist = True
FLAG_rmse = False
FLAG_kernel = False

lr_G = 0.002
lr_D = 0.0002
lgp = 10

sufix = "comb_"+str(lr_G)+"_"+str(lr_D)+"_lambda_"+str(lgp)

table = {
    "Gravity": "fake_set_gravity.txt",
    "Radiation": "fake_set_radiation.txt",
    "Random_Weighted": "fake_set_random_weighted.txt",
    "Random": "fake_set_random.txt",
    "MoGAN": "fake_set_mogan.txt",
    "WMoGAN": "fake_set_wmogan.txt"
}
transp = 'generations/'
city = 'dia'

# %%
print('base')
print("--------")
print("--------")
# with open("./" + transp + city + "/v_test.txt", "rb") as fp:  # Unpickling
#         v_test = pickle.load(fp)
# distanze = np.load("./" + transp + city + "/dist_mat.npy")
# np.fill_diagonal(distanze, 0.01)

if FLAG_weights:
    exp_weight_1_sim = get_exp_dist(v_test)
    print("exp_weight_1_sim")
    # with open(
    #     "./" + transp + city + "/experiments/weight/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_weight_1_sim, fp)

# if FLAG_weights_dist:
    # exp_weight_dist_1_sim = get_exp_dist(
    #     v_test, method="weight-dist", distanze=distanze
    # )
    # print("exp_weight_dist_1_sim")
    # with open(
    #     "./" + transp + city + "/experiments/weightdist/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_weight_dist_1_sim, fp)

if FLAG_cutnorm:
    exp_cutnorm_1_sim = get_exp_measures(v_test, method="cutnorm")
    print("exp_cutnorm_1_sim")
    # with open(
    #     "./" + transp + city + "/experiments/cutnorm/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_cutnorm_1_sim, fp)

if FLAG_cpc:
    exp_cpc_1_sim = get_exp_measures(v_test, method="cpc")
    print("exp_cpc_1_sim")
    # with open(
    #     "./" + transp + city + "/experiments/cpc/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_cpc_1_sim, fp)

if FLAG_rmse:
    exp_rmse_1_sim = get_exp_measures(v_test, method="rmse")
    print("exp_rmse_1_sim")
    # with open(
    #     "./" + transp + city + "/experiments/rmse/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_rmse_1_sim, fp)

if FLAG_kernel:
    start = time.time()
    exp_kernel_1_sim = get_exp_kernel(v_test)
    end = time.time()
    print("exp_kernel_1_sim")
    elapsed_time = (end - start) / 60
    print("elapsed time in minutes: " + str(elapsed_time))
    # with open(
    #     "./" + transp + city + "/experiments/kernel/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_kernel_1_sim, fp)

if FLAG_topo:
    # f = open(transp + city + ".txt", "a")
    start = time.time()
    exp_topo_1_sim = get_exp_measures(v_test, method="topo")
    # f.write("exp_topo_1_sim\n")
    # print("exp_topo_1_sim")
    end = time.time()
    elapsed_time = (end - start) / 60
    print("elapsed time in minutes: " + str(elapsed_time))
    # f.write("elapsed time in minutes: " + str(elapsed_time) + "\n")
    # with open(
    #     "./" + transp + city + "/experiments/topo/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_topo_1_sim, fp)

if FLAG_degree:
    start = time.time()
    exp_degree_1_sim = get_exp_measures(v_test, method="degree")
    print("exp_degree_1_sim")
    end = time.time()
    elapsed_time = (end - start) / 60
    print("elapsed time in minutes: " + str(elapsed_time))
    # with open(
    #     "./" + transp + city + "/experiments/degree/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_degree_1_sim, fp)

if FLAG_indegree:
    start = time.time()
    exp_indegree_1_sim = get_exp_measures(v_test, method="indegree")
    print("exp_indegree_1_sim")
    end = time.time()
    elapsed_time = (end - start) / 60
    print("elapsed time in minutes: " + str(elapsed_time))
    # with open(
    #     "./" + transp + city + "/experiments/indegree/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_indegree_1_sim, fp)

if FLAG_outdegree:
    start = time.time()
    exp_outdegree_1_sim = get_exp_measures(v_test, method="outdegree")
    print("exp_outdegree_1_sim")
    end = time.time()
    elapsed_time = (end - start) / 60
    print("elapsed time in minutes: " + str(elapsed_time))
    # with open(
    #     "./" + transp + city + "/experiments/outdegree/" + model + "/1.txt", "wb"
    # ) as fp:  # Pickling
    #     pickle.dump(exp_outdegree_1_sim, fp)

for model in models:
    print(model)
    print("--------")
    print("--------")
    

    with open("./" + transp + city + "/" + table[model], "rb") as fp:  # Unpickling
        fake_set = pickle.load(fp)
    # with open("./" + transp + city + "/v_test.txt", "rb") as fp:  # Unpickling
    #     v_test = pickle.load(fp)


    number_of_items = np.floor(len(v_test) / (1.5)).astype(int)
    uno = sample(v_test, number_of_items)
    due = sample(fake_set, number_of_items)
    mixed_set_pairs = [pair for pair in itertools.product(uno, due)]
    print(len(fake_set), len(v_test), len(mixed_set_pairs), number_of_items)
    
    ##-------------------------------------------------------##
    ##-------------------------------------------------------##
    ##-------------------------------------------------------##
    if FLAG_weights:
        # exp_weight_1_sim = get_exp_dist(v_test)
        # print("exp_weight_1_sim")
        exp_weight_2_sim = get_exp_dist(fake_set)
        print("exp_weight_2_sim",len(exp_weight_2_sim))
        exp_weight_3_sim = get_exp_dist(mixed_set_pairs, paired=True)
        print("exp_weight_3_sim",len(exp_weight_3_sim))

        with open(
            "./" + transp + city + "/experiments/weight/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_weight_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/weight/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_weight_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/weight/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_weight_3_sim, fp)

    if FLAG_weights_dist:
        # exp_weight_dist_1_sim = get_exp_dist(
        #     v_test, method="weight-dist", distanze=distanze
        # )
        # print("exp_weight_dist_1_sim")
        exp_weight_dist_2_sim = get_exp_dist(
            fake_set, method="weight-dist", distanze=distanze
        )
        print("exp_weight_dist_2_sim")
        exp_weight_dist_3_sim = get_exp_dist(
            mixed_set_pairs, paired=True, method="weight-dist", distanze=distanze
        )
        print("exp_weight_dist_3_sim")

        with open(
            "./" + transp + city + "/experiments/weightdist/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_weight_dist_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/weightdist/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_weight_dist_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/weightdist/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_weight_dist_3_sim, fp)

    if FLAG_cutnorm:
        # exp_cutnorm_1_sim = get_exp_measures(v_test, method="cutnorm")
        # print("exp_cutnorm_1_sim")
        exp_cutnorm_2_sim = get_exp_measures(fake_set, method="cutnorm")
        print("exp_cutnorm_2_sim")
        exp_cutnorm_3_sim = get_exp_measures(
            mixed_set_pairs, paired=True, method="cutnorm"
        )
        print("exp_cutnorm_3_sim")

        with open(
            "./" + transp + city + "/experiments/cutnorm/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_cutnorm_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/cutnorm/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_cutnorm_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/cutnorm/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_cutnorm_3_sim, fp)

    if FLAG_cpc:
        # exp_cpc_1_sim = get_exp_measures(v_test, method="cpc")
        # print("exp_cpc_1_sim")
        exp_cpc_2_sim = get_exp_measures(fake_set, method="cpc")
        print("exp_cpc_2_sim")
        exp_cpc_3_sim = get_exp_measures(mixed_set_pairs, paired=True, method="cpc")
        print("exp_cpc_3_sim")

        with open(
            "./" + transp + city + "/experiments/cpc/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_cpc_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/cpc/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_cpc_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/cpc/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_cpc_3_sim, fp)

    if FLAG_rmse:
        # exp_rmse_1_sim = get_exp_measures(v_test, method="rmse")
        # print("exp_rmse_1_sim")
        exp_rmse_2_sim = get_exp_measures(fake_set, method="rmse")
        print("exp_rmse_2_sim")
        exp_rmse_3_sim = get_exp_measures(mixed_set_pairs, paired=True, method="rmse")
        print("exp_rmse_3_sim")

        with open(
            "./" + transp + city + "/experiments/rmse/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_rmse_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/rmse/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_rmse_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/rmse/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_rmse_3_sim, fp)

    if FLAG_kernel:
        # start = time.time()
        # exp_kernel_1_sim = get_exp_kernel(v_test)
        # end = time.time()
        # print("exp_kernel_1_sim")
        # elapsed_time = (end - start) / 60
        # print("elapsed time in minutes: " + str(elapsed_time))

        start = time.time()
        exp_kernel_2_sim = get_exp_kernel(fake_set)
        end = time.time()
        print("exp_kernel_2_sim")
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))

        start = time.time()
        exp_kernel_3_sim = get_exp_kernel(mixed_set_pairs, True, uno, due)
        end = time.time()
        print("exp_kernel_3_sim")
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))

        with open(
            "./" + transp + city + "/experiments/kernel/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_kernel_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/kernel/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_kernel_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/kernel/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_kernel_3_sim, fp)

    if FLAG_topo:

        # f = open(transp + city + ".txt", "a")
        # start = time.time()
        # exp_topo_1_sim = get_exp_measures(v_test, method="topo")
        # f.write("exp_topo_1_sim\n")
        # # print("exp_topo_1_sim")
        # end = time.time()
        # elapsed_time = (end - start) / 60
        # # print("elapsed time in minutes: " + str(elapsed_time))
        # f.write("elapsed time in minutes: " + str(elapsed_time) + "\n")

        start = time.time()
        exp_topo_2_sim = get_exp_measures(fake_set, method="topo")
        # f.write("exp_topo_2_sim\n")
        print("exp_topo_2_sim")
        end = time.time()
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))
        # f.write("elapsed time in minutes: " + str(elapsed_time) + "\n")

        start = time.time()
        exp_topo_3_sim = get_exp_measures(mixed_set_pairs, paired=True, method="topo")
        # f.write("exp_topo_3_sim\n")
        print("exp_topo_3_sim")
        end = time.time()
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))
        # f.write("elapsed time in minutes: " + str(elapsed_time) + "\n")

        # f.close()

        with open(
            "./" + transp + city + "/experiments/topo/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_topo_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/topo/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_topo_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/topo/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_topo_3_sim, fp)

    if FLAG_degree:
        # start = time.time()
        # exp_degree_1_sim = get_exp_measures(v_test, method="degree")
        # print("exp_degree_1_sim")
        # end = time.time()
        # elapsed_time = (end - start) / 60
        # print("elapsed time in minutes: " + str(elapsed_time))

        start = time.time()
        exp_degree_2_sim = get_exp_measures(fake_set, method="degree")
        print("exp_degree_2_sim")
        end = time.time()
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))

        start = time.time()
        exp_degree_3_sim = get_exp_measures(
            mixed_set_pairs, paired=True, method="degree"
        )
        print("exp_degree_3_sim")
        end = time.time()
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))

        with open(
            "./" + transp + city + "/experiments/degree/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_degree_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/degree/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_degree_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/degree/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_degree_3_sim, fp)

    if FLAG_indegree:
        # start = time.time()
        # exp_indegree_1_sim = get_exp_measures(v_test, method="indegree")
        # print("exp_indegree_1_sim")
        # end = time.time()
        # elapsed_time = (end - start) / 60
        # print("elapsed time in minutes: " + str(elapsed_time))

        start = time.time()
        exp_indegree_2_sim = get_exp_measures(fake_set, method="indegree")
        print("exp_indegree_2_sim")
        end = time.time()
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))

        start = time.time()
        exp_indegree_3_sim = get_exp_measures(
            mixed_set_pairs, paired=True, method="indegree"
        )
        print("exp_indegree_3_sim")
        end = time.time()
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))

        with open(
            "./" + transp + city + "/experiments/indegree/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_indegree_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/indegree/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_indegree_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/indegree/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_indegree_3_sim, fp)

    if FLAG_outdegree:
        # start = time.time()
        # exp_outdegree_1_sim = get_exp_measures(v_test, method="outdegree")
        # print("exp_outdegree_1_sim")
        # end = time.time()
        # elapsed_time = (end - start) / 60
        # print("elapsed time in minutes: " + str(elapsed_time))

        start = time.time()
        exp_outdegree_2_sim = get_exp_measures(fake_set, method="outdegree")
        print("exp_outdegree_2_sim")
        end = time.time()
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))

        start = time.time()
        exp_outdegree_3_sim = get_exp_measures(
            mixed_set_pairs, paired=True, method="outdegree"
        )
        print("exp_outdegree_3_sim")
        end = time.time()
        elapsed_time = (end - start) / 60
        print("elapsed time in minutes: " + str(elapsed_time))

        with open(
            "./" + transp + city + "/experiments/outdegree/" + model + "/1.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_outdegree_1_sim, fp)
        with open(
            "./" + transp + city + "/experiments/outdegree/" + model + "/2.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_outdegree_2_sim, fp)
        with open(
            "./" + transp + city + "/experiments/outdegree/" + model + "/3.txt", "wb"
        ) as fp:  # Pickling
            pickle.dump(exp_outdegree_3_sim, fp)
# Out:
# base
# --------
# --------
# WMoGAN
# --------
# --------
# 346 346 52900 230
# exp_weight_dist_2_sim
# exp_weight_dist_3_sim
